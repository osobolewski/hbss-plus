# %%
from random import randint
from hashlib import sha3_256, sha3_512

key_hash = sha3_512

def hash_j(j, bts):
    # Defines an independent hash function for index j
    return sha3_256(bts + str(j).encode()).digest()

def hbss_keygen(m, key_length):
    # Keygen function for classic HBSS scheme
    preimages = [[], []]
    commitements = [[], []]
    for j in range(m):
        preimages[0].append(randint(2**(key_length - 1), 2**key_length - 1))
        preimages[1].append(randint(2**(key_length - 1), 2**key_length - 1))
        commitements[0].append(key_hash(str(preimages[0][j]).encode()).digest())
        commitements[1].append(key_hash(str(preimages[1][j]).encode()).digest())

    return preimages, commitements

def hbss_sign(message, preimages, k, ij_used = None):
    # Signing function for classic HBSS scheme
    h = int(key_hash(message.encode()).hexdigest(), 16)
    D = [(h & 2**i) >> (i)  for i in range(h.bit_length())]
    m = len(preimages[0])

    j = 0
    while k > len(D):
        h = int(key_hash(str(j).encode() + message.encode()).hexdigest(), 16)
        D += [(h & 2**i) >> (i) for i in range(h.bit_length())]
        j +=1

    signature = []
    for j in range(k):
        i_j = int.from_bytes(hash_j(j, message.encode()), byteorder='big') % m
        if ij_used is not None:
            ij_used.append(i_j)
        signature.append(preimages[D[j]][i_j])

    return signature

def hbss_verify(message, signature, commitements, k):
    # Verification function for classic HBSS scheme
    h = int(key_hash(message.encode()).hexdigest(), 16)
    D = [(h & 2**i) >> (i) for i in range(h.bit_length())]
    m = len(commitements[0])

    j = 0
    while k > len(D):
        h = int(key_hash(str(j).encode() + message.encode()).hexdigest(), 16)
        D += [(h & 2**i) >> (i) for i in range(h.bit_length())]
        j +=1

    for j in range(k):
        i_j = int.from_bytes(hash_j(j, message.encode()), byteorder='big') % m
        if sha3_512(str(signature[j]).encode()).digest() != commitements[D[j]][i_j]:
            return False

    return True

def test_hbss():
    m = 1000
    key_length = 256
    k = 5
    message = "Hello, world!"

    preimages, commitements = hbss_keygen(m, key_length)
    print(preimages[0], preimages[1], sep='\n')
    print(commitements[0], commitements[1], sep='\n')
    signature = hbss_sign(message, preimages, k)
    print(signature)
    assert hbss_verify(message, signature, commitements, k)

test_hbss()
# Out:
# [66129462520702008707821326115149224314807427207042017629340795730112329589488, 92525640730741831449956939080229961462842978123080162397711016833262631445389, 59625058688501620777874665015643479848781910693617565897236545467953660262189, 74337404845449418870834962199977772420125850066522756153425556097480418695002, 63648209325355599749618010866032248038367400534496302296460024251562004817353, 89534956496686351649802056047855133607738607713303711726922081202477380501982, 62123010315226375977754753363382237672610214761904992074044689775291599248382, 68861141717354348439699333054375198000695866976440933692853964504968035633995, 90397672247919168548289334957182175274404966506249543475362433256656778485945, 103176434590258843917122206192838671638608765738010545315789404895249244825225, 106315739535378531452927184615360324281413858930369529926476259182415701168879, 89360735798421925803112501848704464647700745796739619018536103391180516393737, 107430574566275662280521927319662179174782029781658586287173973073664055694984, 88324523474329990971174277604771004056996181870240338687280232809048889746089, 94886118139749275938772735019764811099289580509100649380329507232035206434837, 81376624615248697552699398553539944365471076176335521719503390882459076326274, 61365027436274771767011262650422574585558531034353862148700845863594120832978, 115663248984493496479969927480200254237962316333361950572963225371116779925205, 82622983666354082949525272116308316203438303055177151497986253872364027335141, 96509302670684872904364206658400040378987993145312819974970238721229879997288, 68226996869805329635752541405076084553775121575452413282472870424667571820262, 77963193612225001194407128958053671879170893522257056324923882847198756847640, 88647941951539178491550210945301929617661101219048478180317788212983948982930, 67792836774167528885100314054359961942924289494373442466564280453592627794855, 83897845035173809086962457073792742033089707893557141695104793397211758637228, 94936405784628625304655807972963978371297925256722016054236039243093082135421, 92855906812667832563559633409070404498862209608786609957057439208565252780396, 64457337624582210094770962068549220361961504673627387704887145567754967079246, 65392780129746082083693634853822050205392819895278265797667398773304786847622, 113378928951583057134084203164113775338514126812413739379751674721486266703242, 80392091117263634514683928511422763906458429061829801960745398627619004588645, 102748345854333058670470794850703187497129989520268825216122185922361627996326, 107489724213172311569634081072767133756629482437400124031831473914102697709480, 98510111024709059544722496653203629287987886932825740062097092110657822095422, 70653671978420210702606094058328075127818562776335450238320496330816895446566, 96694331232995728539703087527941797678192132766204903839226553403424984941494, 114837010414715596523424075430639437900628084940351371993191924126596493351546, 98583498958782425732011070379270797030412607659618159626462665116472876398695, 67745324118949366513889637346757944226493552456900061941379393189959105199020, 110564503887881212600858048223991667570497366278930868116187592733270832594924, 93116699917812464899499658499602890185092556485020182563952882031660346203230, 86603755098088181659233059215845610302993108803551217713311347700340867713827, 90765079729944319469734914199014462829567605090513484061356703867358551526323, 81050693356168700907522787331459263437514699284553185831937552745202157239395, 66849497646781594611111351752931188103945724193834175517645706288267373234981, 78129961832259150662262965299847749770189347852982672708349785517817451083266, 102563922841814435446917278835199943591135875364136647123689706259665205853970, 90035168325649194507005072959266368375751482024552162631658070953852485060211, 104467171352294186263368857711372749739846964026664416100193686556020758322389, 66588080237342910235138794987209253534310876074707316450942501912593771891217, 11037014245004084205108057354774954451 ...
# [59543151144274100296015892126969019893780140941998562150192072864001642536544, 90609698077934614841184827221012192282706317458208612007306188420090985715559, 99967328338603222865871461594166497459022984087650452812226275428892164512633, 59141533597652102962611080208709891576029800808507404673501419270291274822084, 63168402067247205637481299586006835394563285292883985557472124744243651326939, 87813932904954932140840068937548786140387638102324394058894522682435532617643, 89002277010383874797917758023377723312937458458838448791675020445930479329607, 111911660484557002690496424563052686781882523872776230105154017768128953362961, 67991766360019956510811190250865359207336482558209985424074175172416730368291, 110708519431080111258531943627004496429123600336554990824869826079199635601155, 76481764582104692125770847469666542750704857890547265258218681384525297971407, 105504343497318079757241193565761777840950020512989996045684960052280741094867, 109203240437796604448983392308215723524980729018589819789936783240208107317192, 95458056302584879053128448769101583623669683341024166626248119743127871231474, 73166689090107460125064593247919338068824317907948367887072714460576021827130, 107074069302122059851067692210256522466909090574685028679976471083449742717047, 111653199955266207680193686246545532993154979048214905966717284489478921271205, 93174525616637445701526443181322253975692221923078831367487047260119841741462, 61071057171357628450176232175816135174803628500347444714490433824318121874204, 108721378049160040635246347233261464167807037464183371939164380035642677813636, 85648671878917427033369024451280063730862494759874665988527353932213494752273, 76296497471812717646110039283063282000623848011026654981286745549585764547786, 109696123494191561038448953763687123546311516648257312491297386113744855582616, 90423735092572172588422225993329352249605941609622445442540726148854272429098, 82824873502612877956806628597967847287564305554820402369463965964099079665038, 80017238707864563355641173335541707754985029903116149250567098066259194747662, 72915799122645335033411557158407878874015718897140540230050456204133833046021, 94548247154866458501728528924572509038080712870770479379315943775264136799467, 86977270107055528553974158617214973784089542393738530942173009256140762166161, 91898191544842798526304203762211706307434054840968517401292137968497539238324, 113155100587010246909623109418453753153791833892248819656229334999313764401883, 106126932252120837779559222432374547850196872505907548789008329575394118944703, 77282742476329943808246184166718804047328721594549681262761866716546165674697, 108201285274738237620179030515708066346528017115764926379017232556743703043294, 73264131957695340628169296396811708522479399454397010492345517108499226400295, 106215894077356146896905329707459156897766428377929927328634993648201147091385, 71690283662122695292258185861121415964322592482318425573595960328842044395101, 59628563012948890364174899100479870289962668130091548192257656756898540265342, 97524797962296306559456868155973606830707271615591695801471909136597480146737, 102898217403585740256054251404875102569192466038990327716536972198227950245442, 66603041235988676376905929826405224867110000497196258636414731198216691873978, 84753400496145084361457724900320420599142403187508054269659504901959030699036, 76850640956034135261842564700385927199397934666963031996617099188927632222940, 58643564890424430473482372435668545061506586158474790081378972516482516523517, 67784813605012821582271024135816408020355842868598179281031528818082403164548, 76006651080968453022424010362252517968174758493215717687448277699279008027307, 76207773176814391421646238737922517513073056492852420980217883078418587836812, 100476944279535587046712133224535616809682220718463795539578886027255592751455, 61471754118831124921823401576273522471331239730560992147320179866206926471459, 99507588569225326059059569606451594910659649425701387413800784804683692080455, 84466371579593504664972929479791061 ...
# [b'\x9e\x13\xd1dBI\x0e&\xf6\x00\xb1\xe2m\x1a=D]\x9c\r\xd0\xcc\xc0\x04[<a\xc7A[\x1e|:\xe9"\xcb\x18:\\\xdf\xd4\xe0\xa6\x89\xe8\xf2&C\n\x8d\x84w\x85\x1f\xf8\xc0\xbd\x01\x95\x0e\x99\x13 \xc6\xb2', b'\xd9Ym\xc1\xf7Y:\xd4\xe4\x05<\x85?\x06\xc7\xb9\xaa\x987y\xc1\x18\xc5S\xdc)\x02\xcf\xa2\xf9\xa7HU\x83\xcf4a\x9c\xe1\xbb6r\xcb\x07v\x82r}\xff\xfc\x9b\x05$c\xbec\x9c\xcc\xe4\xba\xf7\x1bD\x03', b'\xdd\xb6\xbd\x0c\xdc\x96\x0e\x0b\x06\x9d\xdc\xd3VA\x7f\x8cW\xf9s\xbe\t\xad\xbb\xac\xae\x1d%Vn\x012G\xb9\xd6\x93\x89\xb8\xde\x024i\xc0\xfe\x97\x8c\x14\x91\x02\x8c\x16-\xa8[\x06\x05%\t\xcf&\x83S\xd9\xb9\xc5', b'"F\xf1\x13<Gm\xaeB\xe2\xc0\x17C*2\x82\xa03\xf4\t(\xc4\xef\x84|\xe7\xec\x0f\x8b\x15,\xfb9I\xe1\xdc\xd9\x0b\xde\xac\xd5\xea/H\x9ey)\xc7u\xb4\xf2\x17B\x14\xc4r\x01Lo\x80\xe4\xf7\xda\x88', b'b\xc5\xdf\xa5O^\xd9@\xcawf\xb9\x91\x06S|\xff\xd21#r2;\xce\xd1\xeb\xf2\x05J\xc6\x93\x01\xb5JxP\\{\xb7\xbd\x07\xc3\x1fW\xd4SO\x02]\xed\xde7C\xee\x94Y\xb9\x08i+\xe6\xa5\x82\x16', b'wk3Y\x1d\xb1z\xb3\x8e\x07A:\x82bN^\xc2D%\xfb\xc6\x03\x161<B6n#R-V)\xdb\x13\xd3\xad\xf5_Z\xa9\xd5W7E\x92\x971\xf5\x8f\x0eA\xc5\xdcqD=#\xfe\x89}\x15eX', b'u\x05\x03D\x97l\xe3\x96x\xe8\xae\xc9\x91B>\xb5\x8bn\xbft+\x8fgX\xef\x99\x7f\t\xcaF\xd3&\x86\xcc\xfe2\xd2\xe3E0Q\x81\x0fvp8\xf2\x8f\xfd{\xe7{\x84\x10\xdf\x85I\xd4\xa2\x04\xde\x98df', b'\x01m\xb6yx\xd0J\x94"\x13gwd>\x95\x9a\xe7\xc3\x9cBWP\xa0\xba\xd9;E\xecZq\xe9B\xd6\xc7\x0e\xabx\x8e0\xd3\x95\xd9\xff\xe2<\xb4J\xe7\xc9\xea\xef\x0bCf\xf6\x17\xa3\x1fLQ\x1f\x16n9', b'<\xd4\xf2\xac\xe1p-[V\x0cW\xf0\xb8\xb4\x82zlfw\xe2\r\xcf\x99\xf5\rG\x84{i\xa3\x84\xf6e\x0ct\xd4<U]\x9b\x88\xadU\xd6:b\x92\x198\xf6m\x1dT\xdb\xa1\xa1Q<x\xcd,\xf8\xfb\x85', b'}aQ\xcdt,m\xad\x9e\x07\xfd\xbc\xc5O\xe9\xbe\x9c\xcdhj\x94\x90B\xba\t\x92\xa9\x87\xfbhW\xd12\xf8\xc44;\x02l\x16\xe5\xad\xafR@vM\xd4\xce^\xf3Fa\x06\xb9\xfb\x13\xa8\xe6G\xc6\xbf#\x1f', b'"\xca\x9fLE\x83\xf8\x8e\xe5\xbc\xfbF\x035Z\xa2\xea\xe074\xba\xfb\xf0\xaa\xbdn\xd7c\xf4\xd2Vo=\x13\xca\xb0\xca\xc2\xe34v\xaes\x7f\xca\x81\x8e|,\x8f\xb7\x90\xc1\xc8`AV\xaf)\x01\x82\x8eO\xc1', b'\x98\x9b\r\xd2\x01\xe5&b\x8f\x9c|&S\x06\xedZ=y\x1a\xb3:\x0c3\xa3Z\x06\\\xe6\xe8\x00Ee\xbc\xd42\xb7\xec\x07\xb5\n\xed7Q\xf3\x8f\x9d\xe1u\xbcN\t\r\x0fh\xf1<\xaeG\x84#\xec\xc4\xe9\xea', b'\x8e\x18,\x05\xe2\x98\xe4\xf7\xad\xb0\xdb\xdf\x8d\x99\xba\xce\x1f\xff.\xb1\xd0\x89\x11\xb1zu4\xfc\xc9\x10\xea"\xc8p\xfe\xcaq\xc2\xe6|\xd2\x9a\x10C\x0f\x0b`\xe9\xcdh\x0b\xc6{\xd7\xe4l$\x9f\x82\t\xf8DS\t', b'\xe4\x1a"[\x02&\xa3\x94\x92\xa6`\x96\x12\x05DeMJE\xdb\xc4\xbc\xda\x96\xe4\x1e\xa8\x98FQ\xba\xdd\xde\xaa\x07\n`\n\x8d\xe3\x18\nJ,V\x81\x103\x8f\xa3\xb3\x12!\x0b\xfa\xff\xe3\x15\xcc\xd0\x07<Av', b'&\xae\xf6\xce\xb0\xca\x8f\xf3\xb7\x046\xab\x87\x1c\xe9\xdf\xeaS\xc9\x9eA&FC\xf1nI\x89\xee\x16<:\x12d\xce2A\xdb^A\r\x82\xb6\xdb\x96\xa0\x9b\x11\xa5\xf5\n\xce\xa2G\x89Z\x8c)\x0bfWM\x90\xff', b'\xbck&\xbaph\x10\x13cl\x06\xf0\xe9\xa6[\x11\xf8\xe0\xb2\x9d)0\xb9k\x10\x96\\v)\xa3,\xf1k\xcb\xd1Q$\xbf\x03\x1d\x9c\x0f\xe7\x90-\x06BL\x97\xe6\xc6{D\x8b\x13\xf7r\x08\x94\x8d}@f\xa2', b'Yi\x9e\x13\x1b^7E\xdb\xd0\xf2i\x99\xb3\x9c\xff\xb4\x9d\x1a\xf9@\x8e`\xe0\xbd\xb2\xe7\xaa\x08b\x07\x14\xc5\xb2d\x1d+q\xb3G\xc6\xb4\xe1t\x0bnZI\xadi\xa2hY*\xdd^3\x86,f(\x16\xb9M', b'W\xad\x03Y\x0f\xef\x00\xf3\n\x85\x87\xf0\xf0\x106\x95\xdea\xfav\xda\xde\xc8\x19rc\x8bHw\x17\x98J?4bct\x1cL\xeb\xa1\xac\xc4\x85G\x80\x18@K\xda\x0b7\xdc\x85\x1b\xff\xc9z\xae@\x82>\xad\x89', b"\n9\xb1\xe5\xff0P\x82\xf4\xcc\xddf\xa2\x150\xdb\xddI\xfd\xd7%\x9d\x1c\xfa\x86\x88'\x87\x82\r\xa3\xd5\xdf\n\xb1\xdd\xdb\xa1\xfc\xff\x17P\xd1o\\\xd34\x1a\x93-qHO1n+\xa8^9\xf8\xf1'\xe7\xee", b'\x05\xf2\xf8@\xd8^}K\xd4\x94\xfc\xc5i[\xc6\x8a\xe28\xf5\x9f\x9c\xd1>\xf6\xa1\xe6\xaf\xfc\xfd\xc2{\x13\x11\xce\xd6\xdd\xe8\xc6\xb3+\\\xa9\xb4C\xd1\x832\xd2\xa0\x8f9UB\xbc\x94\xb3K<\x92\xfdB\xfe"\x1b', b"\x84\xcf\xfb\x19\xa2KO\xbfe{[\xa2H\xf6\xeb\xd41\x10\xc7\x15K\x98<6\xb8\x8f\x12\xf2\x9b\xd0\xe7\x9cy\xd9\xbc\xb7(S\xb7~\xf8\x99<\xdd\xb9P\x1f!0\xa1\xb4\xe5\x15\xa5\x9b\x06\x03\xea{\xd9\x9e\xeb'\xab", b'\xe9\x88B\x91\x18\x1f\xac\xe7?6\xf3,=\xc7\x83^\xd ...
# [b'J$T\xd5\x8a\x1e\xeed\x9c\x03Jf;\x08\x95S\xf7Sl\x10\xd6\xc3\x94\xca\x8etz\xe7\xe3l\\\xe2\xbc\xdc\x9eFK\x92\xcfC\x85o\xf2\xb8^\xdeC\xf8O\xb9\x9a\x92\x0b\xfd\x15m1E"\xa2\xf5\xbbX\x89', b' \x9e![\xbd\xf9~\x18hB\xfc\xdb\xefg9\xea)\xac\xf4\xb7\x0b[@\xbcQ\xd2>\x19\xe37\xddN{Q\x0eaH6l9\xf5\xcb\xce]\xee\x91r\x1a\x86\xaa\x0f\xee\x8d\x17\xb3\xee\x0b\x1c\xf5@U\xfa\x7fw', b'\xd7\x18*\xcbx\xbf\xb2\x12b\xb0R\xcc\xf8\x89\xf2\xd0H\x87M\xa1t\x13\x19\xaf\x91A\xbd\xc0\xcd}\x05\x82\xf27\x93A\xec\xa2\xa8N00[QF9\xee$\xe4M@`_\x94r\xd1\n\x83x\x15\x85\x85\x9c\x06', b'\xd3\x060\x10\x83J\xd6\x14\xdf\xc59 }\xce\x96\xc4\xb5\xae\xeb\x8a\x00X\xa2~\x13g\xc95oX\xec\x97.M\x1f\xa3]a\x9b\xfd\x02\xb3\x99&0\x92\x08\x13;\xc1\xccl\x05u\xe00\xa7Y\x14\x1b\xd0h\xac\xbd', b'\xd8\xb3\xee\xcaD\xe0\xe2\x01C\x15\xaa_D\xd7\xaa\xa4n\xd7U\x14\xd3:\x96;\x93i\xd9\n\x881\xd19\xe4\x97g?ck\xbeJ\xccO\x8b\x07N\xeb\x11\xb7\xfb\xf2\xb8\xdb\xa0\x9b\x15\xd7\x06\x16n\xcdz\x90\xb9\xc4', b"+f\xf4\xbcE,DqyrmV\xe0\x01\xeb\x95C\x7f>\xef\x9d|\xb5\xc0',\x11\xc7e\x03\xa1\xecj\xf3\x06:@\x1c\xab\xdd\x84*\xca\x88PZL\xedoy\x8d)e\xbd\x8b\xc8d\xf0\xd9yg\x83\xef!", b'Xsh\xe6;K\x1a\xa9|\x16c\xb8\xf3tg\xd1-X\xd6\xa7Jk8\x82\x0f\x01\x88/\xa6\na\xd8<\xe5MF\xce\xba\x80C\xb9<}\x80?\xeePz\xb4M\x90p}\t\xbc@+\xf9a\xa7\xb6\xd6b\xcd', b'\xc8\xa7\xf4\x04\x99\x0e#rq\x08p\xe6\xc8\xac\xffx\xa9\x9e\xe6\x11\xa6\r\xb0\x15\x91*\x0fXB\x13\x8d\x9f\xbd\x9cK\x1175\xc3\x04\x90=\x9e\xfbj\x08iwAf\xa8]l\x93\x07CR1\xad\x80Q\xd8GF', b'i\\\xe1\x80\xd0\xa4\x8e\xa2\xe5n\xb2?\x08\x91e{s\xca\xf7[NN\xb7fG\xeb\xa3&l\x02\xbfw\xa6\xa9b\xfaG%\xe6N\x02e\xe14\xc4>(u\x04\xe3v\\\xc3$\xdb9U\xe4i\x1axf\x83\x1b', b'\xc0\x9bR\x0e>\x93\x1a\x88\xda\xc0\xd3\xd8\xaa\x86N\xf7\x1dP\xdb\x15\xc7\xa4\xc6\xcc\x8f\xf6\x8a\xd8Y\xb37\xdf\xfa\x11\xc5\x9ci\xfa\xc6\x0c\xa2\xcf\x9b\x15\xc9C\x81\x1b@\x15}&\xf4p\xb62\x88\xa3\x06,_\xc0{\xa7', b'\x04\xbbI/\xad\x99+TR\xe4D\x88>\x82\x14\x85\n\xff\xf5\x1a\x1a\xa7\x10\xe5\xa2\x10\xe6\xbaP%v9\x93\x88\xbb\r\xd1G\xca\x8b\xeb!A*<\x82,p\x11\x9b-\x8a\x11\xbe\x92-g6G\xbe\x88#\xb5\xe5', b'\x96\xa2i\xd2\xa1\xe0\xe6Ru\xbe\xf3%\xf6\x10\xf0\x95\x84\x89\x01\x9e\x96}\x1fe\xaak\x08\xbf=U]<\x1ff\xbc\x14V0\x8dO,r\x07\xf3t\x8bXje\x92\xb0T37\xfc\xb6&\xe0\xd1\xd5\xf2]\x8d\xcf', b'P+i\xb5n\xaeW\r\r\xa7\xf3w\xc1\x90)\xcb\xb9Pc<\xd1\x0b\x12\xd3\xa0E\x064n\xd5\xec\x8b@\xf5x/\xe4W\x0736\xc2r\x86[\xfb4\x8f\xde\x05\xa8\x8a}_\xe0\xf2,:xy\xdc=f>', b'\xb9\xcc\x87\x10\x018\xbc\x8b\x85\x84\x8c\x9e:WR\xeaQ\xca\xfeb\n\xaap\x8a\xb6\x97r\xe0\xb9\xd9\x0e\x1d\xd0_\xd7\\\xe1Xd\x87c\x9a\x14\xa9\x92"\x82\xd4\xb2\xce\xb0-\xeeJ;}<\xb5\xe1\xb5\xed\x1d\xe9\x18', b"\x0b\xdf\xb5\xb1\x9dk\xda\xf7C\xcc\x90 \x95n\xde\xf4\xe6\x84c\x84\xd8wO\xa8c\xaf\xe7b\x98}\xa6\xd2(.\x19\xed\xf0'\x91\xb2\x03KZ4+\xb5h\xf3\xda\xa2\xc3\xdcI\xe0\x08\xe5)\xff\xa2\x89\x13TsS", b'\xde\x88UCI]\xc2~\x7f\xe0\x14M\x82\x91\xca\x1eR7\xbdL\xcb\x14A\xd7*\x1d\xc6\xd1\xa1u\xe3\x1c2\xd6r\x0f\xddC\t7X0\x82\xfe\xc7R#\xa0\xb3\xf9\x8f\xeewy\xcf[U8\xe3$j\xfe\xa9\x14', b'\x907`Yv\xb6"ND{\xbd\xa54\xb5\xe7\xbc\xe9\x85a\x02:O\xa8o\x0es\x9f\x98\x89\xfb\x9f\x90`\xd0\xfb\xbd\t\xca\x03m\x02"\x9c\xd6l1\x8b\x8aI\x1bz\x13b\x84|\xf2\xed\x90I\xf6\xd3\x08\xfbH', b'\x81\xfd!\x17\xe4]\xd5\xa7\xc2\x92\xeb4?\xd2\xeb\x0c\xd4\x13\x8c\xa6B\xa5U]\xb4\x90s\xefB.\xcd\x14\x96\x96O\xb9\xeeG\xa9\xb5\xdaW\x18\xd8\xc0b\r\xdf!\xb4\xd2d \xfb\xf8_\xd59\xe8\xf6%\x85r\xfc', b'\xfc\xce\x06\xd8\x8d\xbbaN\xde\xfe{q\x1fJ\xf1\xdd\x0b\xd7\x8eJk\x87\xbe\xa7\x87C\x03\xe3\xea\xbd\xfb\xc4\x93\xfd\n\xa5\xe4\x8dG\xfar\x14\x0b\x1b\xa7n\ta\xac\x8ei\x81\xd6\xd9c\x05_\xd3^Z\xe9\xe0\xdfq', b'\n7D^D\xad\x06)"\xb9t\xf5\x19r\xc7LXn\xdd\xc9\t\xb3\xaa\xc8\x01M\x14\xb3\xc0\t\x957\xea\xa6\xff\xbb\xf7\x85MO\xc3`\x079\xb5\xf8\xe2\x1e\xa7\xbb".\x8c\xb8\xe6)\xe2M\x80\xfe\x86?y\x1b', b'm\xdd\x15G\xab\xe2\xc2\x83%X\xaao\xb4\xb4J\x81Y?e\x19a-\r\xbf\xd3\xff\xe9\xa7\x96\xf7q#:\xfb\xe2\xb2\x97\x0b\xb5\xc2\xcd\x0b\xa4yPF\xb9\xbcK\xf4\x11,\x9e\xf2\t\xd5.\tW\x04B\xb3\xd2\xdb', b"9\xa1\x95.:\xf3\xc5\xae( S\xe2\x9f>\x0e\xfa_\xd8\x1a\xd35\xa2\xee\\\xc3\xdf\xd0\xbaY\xaa\xa0\xa3\xa8\x ...
# [100324738594324319507983838332673783922628819478243546963709411121678492639038, 94869588805641823202622896126900625629918109953912238524302825340741713200893, 76752652626407804206282470744512657130220362282188912063660754995461432182259, 96444491564635349535739854541980084044431703387317525016119703231914586202053, 62435786774222093614547263074633322112184160483321632525465807237068087139525]

# %%
from random import randint
from hashlib import sha3_256, sha3_512

key_hash = sha3_512

def hash_l_fold(l, bts):
    # hashes l times the input bytes
    for _ in range(l):
        bts = key_hash(bts).digest()
    return bts

def hash_j(j, bts):
    # Defines an independent hash function for index j
    return sha3_256(bts + str(j).encode()).digest()

def f(l, message, k, beta):
    # functionality for finding depths given a probability vector beta
    ds = []
    for j in range(k):
        S = sha3_256(b"depth" + str(j).encode() + message.encode())
        len = S.digest_size * 8
        S = int.from_bytes(S.digest(), byteorder='big')

        for d in range(1, l + 1):
            if S < sum(beta[:d]) * 2**(len) or d == l:
                ds.append(d)
                break
    return ds

def hbss_plus_keygen(m, l, key_length):
    # Keygen function for HBSS+ scheme
    preimages = [[], []]
    commitements = [[], []]
    for j in range(m):
        preimages[0].append(randint(2**(key_length - 1), 2**key_length - 1).to_bytes(key_length // 8, byteorder='big'))
        preimages[1].append(randint(2**(key_length - 1), 2**key_length - 1).to_bytes(key_length // 8, byteorder='big'))

        commitements[0].append(hash_l_fold(l, preimages[0][j]))
        commitements[1].append(hash_l_fold(l, preimages[1][j]))

    return preimages, commitements

def hbss_plus_sign(message, preimages, k, l, beta, ij_used = None):
    # Signing function for HBSS+ scheme
    h = int(key_hash(message.encode()).hexdigest(), 16)
    D = [(h & 2**i) >> (i)  for i in range(h.bit_length())]
    m = len(preimages[0])
    
    j = 0
    while k > len(D):
        h = int(key_hash(str(j).encode() + message.encode()).hexdigest(), 16)
        D += [(h & 2**i) >> (i) for i in range(h.bit_length())]
        j +=1
    
    signature = []
    ds = f(l, message, k, beta)
    for j in range(k):
        i_j = int.from_bytes(hash_j(j, message.encode()), byteorder='big') % m
        if ij_used is not None:
            ij_used.append((i_j, ds[j]))
        signature.append(hash_l_fold(l - ds[j], preimages[D[j]][i_j]))

    return signature

def hbss_plus_verify(message, signature, commitements, k, l, beta):
    # Verification function for HBSS+ scheme
    h = int(key_hash(message.encode()).hexdigest(), 16)
    D = [(h & 2**i) >> (i) for i in range(h.bit_length())]
    m = len(commitements[0])

    j = 0
    while k > len(D):
        h = int(key_hash(str(j).encode() + message.encode()).hexdigest(), 16)
        D += [(h & 2**i) >> (i) for i in range(h.bit_length())]
        j +=1

    ds = f(l, message, k, beta)
    for j in range(k):
        i_j = int.from_bytes(hash_j(j, message.encode()), byteorder='big') % m
        if hash_l_fold(ds[j], signature[j]) != commitements[D[j]][i_j]:
            return False

    return True
        
def test_hbss_plus():
    m = 10
    key_length = 256
    k = 10
    l = 3
    beta = [0.5, 0.25, 0.25]
    message = "Hello, world!"

    preimages, commitements = hbss_plus_keygen(m, l, key_length)
    print(preimages[0], preimages[1], sep='\n')
    print(commitements[0], commitements[1], sep='\n')
    signature = hbss_plus_sign(message, preimages, k, l, beta)
    print(signature)
    assert hbss_plus_verify(message, signature, commitements, k, l, beta)

test_hbss_plus()
# Out:
# [b'\xb6\x94\\\xa6P\xafGb\x01\xcf\x03J\xd2\xb2\x92%\xe2\x1c\xc9\xb6\xbc\xbe\xb2\xf2\x99#\xae\r\n\xbb\x9cv', b'\xef\xf3\x12\xe8\xcf\x86\xb7\x1b-\x9f\x11\xca\x8c\x0e\x03!Tf{\xa8\t0F\xfa0\x90^g6\x03\xf9?', b'\xb5\xc0\xfb\x93\xd3\tW\xa2\xde\xa0\xd7\x8c+F\x19.K\xc7\xe8\x16\xceE:n\x0b\xee\xf8AKq\x86\x87', b'\xff\xaa\xfbr\xb2\xf6+\x1c\xe2\xcf\x8b\xe7}\xb2\xc4\xdb5f\xe8M\\r\x10ap\x07\xce\xf6J\xed\xf4\x03', b'\xf8\xb36\x83\xeaP9],\xe9\xee\xa14\xf7\x91\xa5\x10/\x89!\x17\x18\x18b3*\xf4\x8b\xb0M\xad&', b'\x82\xa0\xbc\xe9\x92\x8c\xe0\xf8\xbc}X\x08y\x03\xfc,zk\xef\xf8\xc5e+w\xc7MY[i\x1a\xeb\xb5', b'\xd5\xe7\x12\x7f\x80y\xe9\xba\xcc\x03t>5\xb0\x1a\xb2\x89\xe5\xb8\xbacu\xad\x12\x14]d\x87=\x89#f', b'\xff\x19d\xe6N.\xb4&7\xd4$2\xe9\xea\xe7\xa2^\xc0\xaeh\x13\x98\x17\x85\xb2m\x93\xd5}h\x9e\xe3', b'\xd2\xeb  \x19\x87\xd9\xc1w\x19\x99}\x1c<\x06\xc9$\xe9\xf9N-r\xf08Ay\xaea!\xc5\x94,', b'\xd4\x10\xfaK\x86\xf1\xdb\x9a:\x7f\x18\xf5\x8b\xddFR\xce\x08\x0b\xfaH\xffu7\x0f\xf5b\x92C\xf1\x9c\x8d']
# [b'\x91\xa8N\x1e\xaf\xcb}~\xc9\xcc\x8e\xf4\xce\xf4\xcd\x14\xe9\xb0\xfd\x18\x189\xe8\xc9i\x8c-\x1d\xbc;l~', b'\xfa[\xd7v\xf5\xbf\x99D\xa7\x04\x04t\xaf\xaa\xcd\xe1F\x90c\xee\xcb.\xddK\xdep\xc6"\xfc\x19\x9dc', b'\x8a\xdd\r>\x8c\xf7\xfd\x82+\x95\x89D\xe1l\xbd\xfaK\x04\xd7\xd4\x9d\x93\x1c\xb4\x10C\x8d\xf8\x95\xe5M8', b'\xd5w\\\xd9g\xabO#\xc1\x01\xdcN\x88\xdb\xad\xc1\xc8\x93\xf2\xff\x815\xc48Z\xadi\xa2\xd0\xeb\x1c\x11', b"\xf9\xf8\xe1\x9c-\xa9\xfa2\x8a\r\xa0'z\xaa\xaf0\x12Z\x10M\xf8\x88\x0f\xf2\xf4?/}O\xf6\x86\xc9", b'\xcf\x9c\x1bw\xe1\x8f\x84\xcb\x97D&\xec]\xb2\xb2N\xc3\xa6\x1fsj\x97\xec\x8a\xb5\xad\x18\xb2\xdf\x8a\x7f\x0b', b'\xe4w\x9a\xb7\xc9\xf9\x04\x96\x8c\xa3F\x85,62\xad\x10\xc7\x07\xe4\x93M\xd9\x88h\x90\xd7\xc6Y\xf2\xa9\xb3', b'\xb0\x13\xec<\xf5^\xe1\xcd\xa7\xc4\t\x07B\xd7I\xa2\xc3\xfe\xd1\xfc\xd70\xe1k\xb5\xdc\xc7? \x8c\xb4/', b'\xd2\x0e(G+\xc4\xdfiY\xcb\r\x86\xd0\xf7p\xe5/\xf3\xba\x863\xf0\xb3v-\xb2_\xfd9-\xc04', b'\xbfB\x95\xae\x8d\xaag?OY1\xdf \x12\xf8\x89\xd3\xc5\xe8\x05\r\xe2\x93\x12\x1a\xd4\x00\xc4\x06\xb0\x9e\x92']
# [b'\xb6e\xb7\xdb>P\xe0\xc5\x04O\xfb\xc1\xd1]\x1bl\x16\x08\x11q\xedu\x85\x90\x8a6KM\x16\xe6\xc2\x01)\x18\xd2=\x1a\x87\x0f\x9b\x88\xd2\\\xb50\x1bV\x0eb\x98\xa3\xb2\xa8\xa7 \xcfP\xde(\xcaY\xcc\xa4\xb8', b'\xd3\xbc\n*f\x94<\xea\xf8\x9b\xfe\x7fL\x91\xa8\xec\xa9\xd0N\xa7x\xce\xcd\\\x94\xf6\x8fL\xff|@\x08\xb0t\xc5\xbcP\xc2o\xedpP\xe0\xb2\x8aB\x13\x8at8\x813\xcd\xc9Hl\xd0\xf6N\x89\x87\xe6\x97;', b'\xce\xb7\xc7<y\xael\xfe\x90\x19\xbf\xa6)\x81b\x92\xd4\r\xebx\x08\xf9s\xb8V\xa6e\x1a{@\xdbf\x03N\xc3\x19w\xc1\xfc\x81~\xbcPqAd\xb1(\xf9\x84\xeck\x9av\x83i! n0;\xc6\xb5\n', b'g\xc4\xba\xab\xce\x17\xba\x05\xea\x90\xd6e\xeb\x11\x0f\x9f\x9cfK\x13\xf3\xa7\xbdWa\xa9\x9bk\xaeZ\x8f\x06\xfe\xc4w\xfa\x9dLKW\xe6\xc6/[\x8c\xab\xf0\xe4D\x92\xc7\x9f\xf9H\rU\xaa6\xedf=["\xfc', b'\x08Mf!\xb1\x0bj\x03\xe0H}\x14\x1e\xa7\x80\xac\xe6X\xd7>\\\xe4\xa0\x84\xe8\xb9i\xaf\xa5\xa7\x83\xeb3v\xc4\xe3\xa78y\xfe\x0c27l\xf9v\x80\xffm\xb6\xc5-8\x10\xc3\x12\x1d\x17\xc8\xe5\x19\xef\xdf\x15', b'\xe2\xc5\xfa<\xcd\xcc=\xfb\xe4\xeeF\x93{\x08\xd5\xea\x1d\xdeG\x1b\xe0\x85r\xaeq\x1e\xee\xe5R\x07\x85X\xaf\x90\xff\xa6\xcf\xef\x19\xe9\xc0M5\x1b\x13LE>\x88\xd2{\xb0\x85\xab|\x9e\xfe52r\xee\xa6\xfat', b'\xf6\xca\xe3\xdd\xde\xdb\xaa\x12\x91\x8a\xae)\x896\\\xbf\xfb\x92\xd2`w\xe2\x9f\xb9\xbee\xbf\x08\xb3\xb8\xe7\x94\x05(p\xe2\xab\xbe}\x85\xb1\x19\x0f\x8c\xdb7\x82D\xf9\x0br\x96"\x17\x18\xa0\xd9\x9bZ\xbe\xd4\xb3nA', b"\xab\xaeK\x9c\x8b\xe8'c\xb8W\xae\xbenZ\xbc\xf0G\x16\xd3\xbf\xb5)o\x94\xa4\x85\xf0\xa7\x01\xd1\x14\x14.\xdaD[\x02\xb3%Ui!\x15\xddV=\x7f\x8b\x8eSXq\xed\x1e:\x04\x9b\x8a\xc3\x04=\x1f\x9c7", b'\xf3s\x97d\xbdi\xd2w\x90:_\xe70/\xeeM\x8b\xcd\x8e-^\x8a\x94HG\xf3VF\xf6\xdf\xdd\xc2> \xc0\x83\x82\x13A\xa9\xfa\x8d;\xc9]YQ\xf9\x9d\x82\x89\x16\x06D?\xd6\xad2\xc9\x93+\xbbE\x1e', b'\x95\x99\x9a\xa77AT\n\xe6t\xff\xa2\x03&\xcf\xebLW\x04m\xf3\rS\xef\xe9^Ve]r2\xe1\x9ceR\xd9\x1f\t\x9f\xd2=\xc6V\x81\xaaP\x19\xea\x97Z\r\xbd\x13I\xd66]\xc3\xae\x11\xde\xb2\r$']
# [b'\xbd\xd9]{5Z\x81\xe8\xcd^\xb1\xcd\x92\x83f\xe2Y\x8dN\x0b\x9c\xf9\x12\xe4\x10\n\xf7cf=5\x9cb\xa2\xdc\xa6\xf01\x86\t\x11T\xb4\x073\xe1O[\xbe\x90\x1fX\xaa8$SS\x85\xb1X\xbeJ\xe0i', b'+K\x97k\xc0\xa6\xb4\x11\xa7\xe4\x9f\xd3#9\xad\xc2\xa5\x93[\x9d\xb2\x8eKlv\xcc\xc1T\xe4[\x8fH\x1bF1D\x1e\x85\x15\x9b\x88(fj!G\xa7\x8c3t\xa6\xfa\xcb\x8d\x88\xd9\xdd(\\\xc9\xe6m\x18|', b'\x92\xe6l?|\xd5\xee\xcbFL\xc5\xf3z\xb7*\xc9<\x03\xc5\xa0b6\xf4\x1d\x91\xaf\xdc!w\xff\xc3/\x1c\x94\xa6\x0f\x8fP`\xd4e\x18\xac\xf9,\x83X\xb7$0\xf5\x9f\x86\xb2~W2\xf5\xa0K\x1b\x9c^-', b'`.\xbf\x80\xd6\xd9}4\xa1\r\xb6\xf13\xda\x11\xb8TR\x90dk\x8d:\x818\x19F\x8f\x8a\xfa~\x11\xd4KX\xf9l\xd9N\xf2s\xa3Y\xe6G\xecc\xa0tjG+\x80\x96\x121\x18\x0c%\n\x8f$\x97\xb8', b"H\xe30\x19I\x1f'/M\x01\xf3\xd2%\x1a\x1e\x9aXa\x8eiR\x10p\x89\xa6\xa8fl\xfc\xd0RJ\x1bC\xe1\x06nf(\x0e\xa5%\xdf\x93K\xdee\x7fK\xb5\xa2\xbe\xc8\xc3\xb2FO\xed\xf7\xb7\x95P-\xcd", b'\x92jd\\6\xb1\xbdr@\x85B\xc7\x1c|\x7f<DgC`\x1aN~\x93e\xd4=\xa1W\xcaR\xda\x93]UR\xaa\xe6l\xb0n\x88\xfd\xa4\x02\xa8\x172Gv=1\x91\x82\xcf\xe5\xe5B\x8d]\x1as\x91\x89', b'\x06\x92\x90\xb3\xe3\x87|\xbe\x8a\x1a\xc8\xe2/\x1e\n\xe0\xa4\xde\xe2\xa4\xb7\xd5\xa0*r\x88\x12\xaaY\xc3\x1e"\xf2!\xb4\xc6J\x8d\xac\xb5,\x95i\xec?\x02\xb3H\xa3\x04]EH\xcb`K/{:\xad\x06\xd5\x89\xf3', b'Hx\xec6\xda\x1c\x87\x8a\xe0\x9cu\x81\xa6\x1c\xd5\x0e\x83\xaf\xe7\xaa\xb9\xffe\x88\x84X\xf9\x16\xc59\x16Y\xd9\xba\xa45A$\xee@\x9d\x18\x91\x01j\xfa~]\x00GV\x94$<\\\xdd\x93\xd5\xa0\xc2\x8b\xca\x89\x98', b'J\x93\xc11\x03\xc9L\xe5MXK\xbc0R\xb4\xc6\xdfb\xed\xf4\xae\x89\xd2\xa8\xd1\xc3\xff\x1a\xd9x^\x870-m\x06\x84\xe0\xb0z)\xd0\x089\x18H\x08\x97[\x92S\x0c3v\x89\x9d\x16Y\xbf\x9dtH\x0c\xbc', b'q\xc6\x81luf\xa9P\xd5KN\x89si\xb1\x14\\_\x94go\xfe\xedE\x0e\x7f\xeb@H\x1fE[{\xe6\xc5yhF)fC\xa8\xaf\xa2\x92\x933\xf9\x96\xb7\xf5\xe8\x9b\xbf\xfe|G\x16`f\x93L\xb4\xa8']
# [b'\xfa[\xd7v\xf5\xbf\x99D\xa7\x04\x04t\xaf\xaa\xcd\xe1F\x90c\xee\xcb.\xddK\xdep\xc6"\xfc\x19\x9dc', b'\x94\xb4\xb4\xf1\xab\xea:\xf0lo\xc0\xf2\xa0o\xa3\x03\x9ebr"K \xea\x1dQ\xdfC:\xb6\xe1\x0f|\xb7\xcf\xf2\x83\x16\xbdw\x8f\xbe?\xdcF\xc9\xbb,\xf8\x8b\xbc\x8ey\x1ep\xbc<\xc2V\xfdA1*\xcaY', b'k\r\xc2=\x8e\xf78$bG:\xa7\xbe\xc6\xccV\xef\n\xe5\x13`c\x11l\xca\xd1\xe2\xf2\x04\x1e\xf4\xd3\xa6\x96[\xeft*\xee\xc3PU\xd7\xa9\x01V\t\xd6\xc3\x903+%A?\x89\xa3y\n*oT\x82\x82', b'\x10\xecD\xd5{FB\xa0\x070\xee\x83r\xa4wB\x0e\x1c\x15lB\x92J.-\xb0\x1eA,b\t\xa530\xc9\xd8Q-\x0e\xede\\\x01\x975\x08\x12\xa1\x10\xb9L\x13\x8a\xab\xa2t\xe3Dk\x078\x9e\x95\xfd', b'-x\x92z\xa5^\x89\xb8v9\xe4\xf2eX\xc9\x0c\x140\x07/\xd0\r\xaf\xbfB4\x8dN\xc4\xb6.\\\x95\xd7\x1di\xf9)l\xf3W\xa1\xd8\x1d8j\x99P\xd3\xb1M\xd2\xa60\x98L<\r\xfa\xdcrm\x8c\x08', b'\x82Q\xc7\x95\xa8\xc3\xc3f\x04%\xdf\x1bZ\x8aN\x94B\xec}NG\xeaL\x10\xa3\xbf\xd1\xdef\xa9L\xf6\x15\xb1\x03mO\x95\xe9\x98\xf7<tj\x158%BeZk=\x00\xa7\xc8\xfdm\x10\xee\x07Em\xf5t', b'\xbf\xd1u\xe1\xbb\x9f$\x00\xbe\xe7\xf7\x82\xab\x94\x02\x97/\xbb\x8f\\\xafKL#z\x90\xb2\xa4\x86\x8e\xd1\xb6\x06\xf9\xa5\xc4{O\xb5\xa2\x0eO]\x06&\xdfE:\xaa\x11\x0b\xaa\xac\xd9c\xc1QU\x06\xa9q\xb3\xa8\xa4', b'M\xed\xe4\x0c\x8cxL~A\x8d\x05>\xd9\xc7QL\xf6\x0e\xba\x9bt\x18@\xc8\xfcMqs\xa9\xe9\xdd[\xa0\xb7\xab\xdb\xa7\x90d\xfc\xab3\x0bX\xf7\xd5a\x1bwg\xaa\xce\x07\x10*\xd4\r\xc8\x88q\x7f\x86\xd5;', b'\xff\xaa\xfbr\xb2\xf6+\x1c\xe2\xcf\x8b\xe7}\xb2\xc4\xdb5f\xe8M\\r\x10ap\x07\xce\xf6J\xed\xf4\x03', b"\x8f\xaa\x98N%1\xe6\xfcl\r)Xk\x12f_X\xd8\x83>?\xcb.8\x1a\x16\xb7n\xb7:\xe5\x15`Z\x1dr\x85\xd7l\xcc~~U!\x7f\xa4\r\xceH\xd2'\x9d\xfa\xd1\xb0:\xeap\xc4z\xef&\xb9\xb5"]

# %%
import time

def signing_experiment(preimages, commitements, k, message, filter):
    # Experiment for signing time
    ijs = []

    start = time.time()
    signature = hbss_sign(message, preimages, k, ijs)
    end = time.time()
    signing_time = end - start

    false_positive = True
    fresh_preimages = 0
    for ij in ijs:
        if ij not in filter:
            false_positive = False
            filter.append(ij)
            fresh_preimages += 1

    start = time.time()
    assert hbss_verify(message, signature, commitements, k)
    end = time.time()
    verification_time = end - start

    return signing_time, verification_time, false_positive, fresh_preimages

def signing_experiment_plus(preimages, commitements, l, k, beta, message, filter):
    # Experiment for signing time
    ijs = []

    start = time.time()
    signature = hbss_plus_sign(message, preimages, k, l, beta, ijs)
    end = time.time()
    signing_time = end - start

    false_positive = True
    fresh_preimages = 0
    for ij, d in ijs:
        if ij not in filter:
            false_positive = False
            filter[ij] = d
            fresh_preimages += 1
        else:
            if filter[ij] > d:
                false_positive = False
                filter[ij] = d
                fresh_preimages += 1

    start = time.time()
    assert hbss_plus_verify(message, signature, commitements, k, l, beta)
    end = time.time()
    verification_time = end - start

    return signing_time, verification_time, false_positive, fresh_preimages

# %%
import gc
import sys

# https://stackoverflow.com/questions/13530762/how-to-know-bytes-size-of-python-object-like-arrays-and-dictionaries-the-simp
def get_obj_size(obj):
    marked = {id(obj)}
    obj_q = [obj]
    sz = 0

    while obj_q:
        sz += sum(map(sys.getsizeof, obj_q))
        all_refr = ((id(o), o) for o in gc.get_referents(*obj_q))
        new_refr = {o_id: o for o_id, o in all_refr if o_id not in marked and not isinstance(o, type)}
        obj_q = new_refr.values()
        marked.update(new_refr.keys())

    return sz

# %%
from math import log, e 
from random import randbytes

m = 2 ** 23
key_length = 512
n = 2 ** 12
k = 512
filter = []

m_plus = 2 ** 19
key_length_plus = 512
k_plus = 1024

filter_plus = {}
beta = [0.3, 0.21, 0.14699999999999996, 0.10289999999999998, 0.07202999999999998, 0.05042099999999998, 0.035294699999999984, 0.02470628999999999, 0.01729440299999999, 0.012106082099999993, 0.008474257469999994, 0.005931980228999996, 0.0041523861602999965, 0.0029066703122099975, 0.002034669218546998, 0.0014242684529828986, 0.000996987917088029, 0.0006978915419616202, 0.0004885240793731341, 0.00034196685556119386]
l = 20

print(k)
print("Prob of false positive for HBSS:", (1 - e ** (-k * (n + 0.5) / (m - 1))) ** k)


signing_time_total = 0
verification_time_total = 0

signing_time_plus_total = 0
verification_time_plus_total = 0

experiments = 10

start = time.time()
preimages_plus, commitements_plus = hbss_plus_keygen(m_plus, l, key_length)
keygen_plus_time = time.time() - start

start = time.time()
preimages, commitements = hbss_keygen(m, key_length)
keygen_time = time.time() - start

print("Keygen time for HBSS:", keygen_time)
print("Keygen time for HBSS+:", keygen_plus_time)

fps = 0
fps_plus = 0

fresh_vals = 0
fresh_vals_plus = 0

for ix in range(experiments):
    message = str(ix) + randbytes(32).hex()

    signing_time, verification_time, fp, fresh = signing_experiment(preimages, commitements, k, message, filter)
    signing_time_plus, verification_time_plus, fp_plus, fresh_plus = signing_experiment_plus(preimages_plus, commitements_plus, l, k_plus, beta, message, filter_plus)

    signing_time_total += signing_time
    verification_time_total += verification_time

    signing_time_plus_total += signing_time_plus
    verification_time_plus_total += verification_time_plus

    fps += int(fp)
    fps_plus += int(fp_plus)

    fresh_vals += fresh
    fresh_vals_plus += fresh_plus

print("Total signing time for HBSS:", signing_time_total)
print("Total verification time for HBSS:", verification_time_total)

print("Total signing time for HBSS+:", signing_time_plus_total)
print("Total verification time for HBSS+:", verification_time_plus_total)

print("Average signing time for HBSS:", signing_time_total/experiments)
print("Average verification time for HBSS:", verification_time_total/experiments)

print("False positives for HBSS:", fps)
print("False positives for HBSS+:", fps_plus)

print("Average fresh values for HBSS:", fresh_vals/experiments)
print("Average fresh values for HBSS+:", fresh_vals_plus/experiments)

print("Fresh values for last experiment for HBSS:", fresh)
print("Fresh values for last experiment for HBSS+:", fresh_plus)

print("Key size for HBSS: (bytes)", get_obj_size(commitements))
print("Key size for HBSS+: (bytes)", get_obj_size(commitements_plus))
# Out:
# 512
# Prob of false positive for HBSS: 0.0
# Keygen time for HBSS: 65.97584557533264
# Keygen time for HBSS+: 21.818665027618408
# Total signing time for HBSS: 0.011536359786987305
# Total verification time for HBSS: 0.020817995071411133
# Total signing time for HBSS+: 0.17783117294311523
# Total verification time for HBSS+: 0.08054876327514648
# Average signing time for HBSS: 0.0011536359786987304
# Average verification time for HBSS: 0.0020817995071411135
# False positives for HBSS: 0
# False positives for HBSS+: 0
# Average fresh values for HBSS: 511.8
# Average fresh values for HBSS+: 1019.3
# Fresh values for last experiment for HBSS: 511
# Fresh values for last experiment for HBSS+: 1015
# Key size for HBSS: (bytes) 1768182264
# Key size for HBSS+: (bytes) 111088568

# %%
def prob_experiment(m, key_length, k, n, preimages = None):
    # Experiment for probability distribution
    if preimages is None:
        preimages, _ = hbss_keygen(m, key_length)
    filter = []

    for i in range(n):
        # genarate n signatures
        message = str(i) + randbytes(32).hex()
        ijs = []
        signature = hbss_sign(message, preimages, k, ijs)
        for ij in ijs:
            if ij not in filter:
                filter.append(ij)


    ijs = []
    message = str(n) + randbytes(32).hex()
    signature = hbss_sign(message, preimages, k, ijs)

    # get fresh preimages for n+1
    false_positive = True
    fresh_preimages = 0
    for ij in ijs:
        if ij not in filter:
            false_positive = False
            filter.append(ij)
            fresh_preimages += 1

    return false_positive, fresh_preimages
        
    
def prob_experiment_plus(m, key_length, l, k, beta, n, preimages = None):
    # Experiment for probability distribution
    if preimages is None:
        preimages, _ = hbss_plus_keygen(m, l, key_length)
    filter = {}

    for i in range(n):
        # genarate n signatures
        message = str(i) + randbytes(32).hex()
        ijs = []
        signature = hbss_plus_sign(message, preimages, k, l, beta, ijs)
        for ij, d in ijs:
            if ij not in filter:
                filter[ij] = d
            else:
                if filter[ij] > d:
                    filter[ij] = d

    ijs = []
    message = str(n) + randbytes(32).hex()
    signature = hbss_plus_sign(message, preimages, k, l, beta, ijs)

    # get fresh preimages for n+1
    false_positive = True
    fresh_preimages = 0
    for ij, d in ijs:
        if ij not in filter:
            false_positive = False
            filter[ij] = d
            fresh_preimages += 1
        else:
            if filter[ij] > d:
                filter[ij] = d
                fresh_preimages += 1

    return false_positive, fresh_preimages

# %%
experiments = 1000

n = 2 ** 5 - 2 ** 3
m = 2 ** 8
key_length = 512
k = int(m/n * log(2, e))

print(k)
print("Theoretical Probability of false positive for HBSS:", (1 - e ** (-k * (n + 0.5) / (m - 1))) ** k)

m_plus = 2 ** 16
key_length_plus = 512
k_plus = int(m/n * log(2, e))

l = 2
beta = [0.8, 0.2]

false_positives = 0
false_positives_plus = 0

fresh_vals = 0
fresh_vals_plus = 0

preimages_plus, _ = hbss_plus_keygen(m_plus, l, key_length_plus)
preimages, _ = hbss_keygen(m, key_length)

for ix in range(experiments):
    false_positive, fresh = prob_experiment(m, key_length, k, n, preimages)
    false_positive_plus, fresh_plus = prob_experiment_plus(m_plus, key_length_plus, l, k_plus, beta, n, preimages_plus)

    false_positives += int(false_positive)
    false_positives_plus += int(false_positive_plus)

    fresh_vals += fresh
    fresh_vals_plus += fresh_plus

print("EXPERIMENTS FOR N+1th SIGNATURE")

print("False positives for HBSS:", false_positives)
print("False positives for HBSS+:", false_positives_plus)

print("Average fresh values for HBSS:", fresh_vals/experiments)
print("Average fresh values for HBSS+:", fresh_vals_plus/experiments)

print("Probability of false positive for HBSS:", false_positives/experiments)
print("Probability of false positive for HBSS+:", false_positives_plus/experiments)
# Out:
# 7
# Theoretical Probability of false positive for HBSS: 0.00674300265862382
# EXPERIMENTS FOR N+1th SIGNATURE
# False positives for HBSS: 11
# False positives for HBSS+: 0
# Average fresh values for HBSS: 3.598
# Average fresh values for HBSS+: 6.976
# Probability of false positive for HBSS: 0.011
# Probability of false positive for HBSS+: 0.0
